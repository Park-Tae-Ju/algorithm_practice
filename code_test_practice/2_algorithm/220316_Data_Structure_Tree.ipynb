# %% [markdown]
# # 트리 자료 구조
# ### 특징
# 1. 부모 노드와 자식 노드의 관계로 표현된다
# 2. 트리의 최상단 노드를 루트 노드라고 한다(root)
# 3. 트리의 최하단 노드를 단말, 리프 노드라고 한다.(leaf)
# 4. 트리의 일부를 떼어내도 트리 구조이며, 이를 서브 트리라고 한다.
# 5. 트리는 파일 시스템과 같이 계층적이고 정렬된 데이터를 다루기에 적합하다.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 이진 탐색 트리
# ![image-2.png](attachment:image-2.png)
#
# - 부모 노드보다 왼쪽 자식 노드가 작다
# - 부모 노드보다 오른쪽 자식 노드가 크다
# - 순서 : 왼쪽<부모<자식순이다
